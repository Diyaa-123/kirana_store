# %%
from db_json import category

# %%
category
# Out:
# [{'vegetables': [{'name': 'Tomatoes',
#     'weight': '1 kg',
#     'cost_per_weight': 40,
#     'image_url': '/static/images/Tomatoes.jpg'},
#    {'name': 'Green Chillies',
#     'weight': '100 gm',
#     'cost_per_weight': 20,
#     'image_url': '/static/images/Green Chillies.jpg'},
#    {'name': 'Onions',
#     'weight': '1 kg',
#     'cost_per_weight': 35,
#     'image_url': '/static/images/Onions.jpg'},
#    {'name': 'Potatoes',
#     'weight': '1 kg',
#     'cost_per_weight': 30,
#     'image_url': '/static/images/Potatoes.jpg'}]},
#  {'fruits': [{'name': 'Banana',
#     'weight': '1 dozen',
#     'cost_per_weight': 50,
#     'image_url': '/static/images/Banana.jpg'},
#    {'name': 'Red Apples',
#     'weight': '1 kg',
#     'cost_per_weight': 120,
#     'image_url': '/static/images/Red Apples.jpg'},
#    {'name': 'Oranges',
#     'weight': '1 kg',
#     'cost_per_weight': 80,
#     'image_url': '/static/images/Oranges.jpg'}]},
#  {'dairy': [{'name': 'Milk',
# ...
